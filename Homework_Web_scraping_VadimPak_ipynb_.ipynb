# %% [markdown]
# #Домашнее задание к лекции «Основы веб-скрапинга»

# %% [markdown]
# Обязательная часть

# %% [markdown]
# Вам необходимо написать функцию, которая будет основана на поиске по сайту habr.com. Функция в качестве параметра должна принимать список запросов для поиска (например, ['python', 'анализ данных']) и на основе материалов, попавших в результаты поиска по каждому запросу, возвращать датафрейм вида:
#
# <дата> - <заголовок> - <ссылка на материал>
#
# В рамках задания предполагается работа только с одной (первой) страницей результатов поисковой выдачи для каждого запроса. Материалы в датафрейме не должны дублироваться, если они попадали в результаты поиска для нескольких запросов из списка.

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
#query = ['python', 'анализ данных']
def habr_scrapper_0(query):
  results = []
  for search_word in query:
    base_url = 'https://habr.com'
    params = {'q': search_word,
          'target_type': 'posts',
          'order': 'relevance'}
    resp = requests.get(base_url + '/ru/search', params)
    resp.status_code
    soup = BeautifulSoup(resp.text)
    for article_tag in soup.find_all('article'):
      h2_tag = article_tag.find('h2')
      #print(h2_tag.prettify)
      title = h2_tag.get_text()
      #print(title)
      try:
        link = h2_tag.find('a').get('href')
      except:
        link = 'Ссылка недоступна'
      #print(link)
      date = article_tag.find('time').get('datetime')
      #print(date)
      results.append([date, title, link])
  
  res_df = pd.DataFrame(results, columns = ['date', 'title', 'link'])
  res_df['link'] = base_url + res_df['link']
  res_df['date'] = pd.to_datetime(res_df['date']).dt.date
  res_df.drop_duplicates()
  res_df.reset_index()
      
  return res_df

query = ['python', 'анализ данных']
habr_scrapper_0(query)
# Out:
#           date                                              title  \
# 0   2022-01-20  Курс «Python для инженеров». Старт 3 потока 31...
# 1   2021-12-13  Жаждущим автоматизации: открытый урок «ChatOps...
# 2   2020-04-21  Вышел Python 2.7.18, последний релиз ветки Pyt...
# 3   2021-07-06  Python Community Meetup 8/07: видео и материал...
# 4   2022-01-13  Открытый урок «Пишем Custom Prometheus Exporte...
# 5   2020-12-04  Python как компилируемый статически типизирова...
# 6   2022-03-08  Вышел мартовский релиз расширения Python для V...
# 7   2020-03-03  В начале этого года Python сместил Java и стал...
# 8   2021-11-16  EPAM разработала бесплатный курс по программир...
# 9   2022-12-26  Positive Technologies открыла доступ по запрос...
# 10  2022-08-19  Осталась неделя до старта 4 потока Python для ...
# 11  2020-06-03  Вышла версия 0.0.2 snakeware — дистрибутива Li...
# 12  2020-11-13  Создатель Python Гвидо ван Россум выходит на р...
# 13  2022-10-25                                  Вышел Python 3.11
# 14  2019-10-31  Создатель Python Гвидо ван Россум ушел из Drop...
# 15  2021-10-06          Вышел язык программирования Python 3.10.0
# 16  2021-10-11  Python вышел на первое место рейтинга TIOBE, и...
# 17  2022-06-03  «Тестирование веб-приложений на Python» — новы...
# 18  2022-08-24  Python, SQL, С и Java стали самыми популярными...
# 19  2022-12-05               Python или Golang: что учить в 2023?
# 20  2012-07-25                      Пять лет Школе анализа данных
# 21  2017-07-25                10 лет Школе анализа данных Яндекса
# 22  2022-08-10  Как за две недели проверить гипотезы применимо...
# 23  2021-01-14  Что такое бессерверный SQL? И как использовать...
# 24  2019-01-21  Как мы строим систему обработки, хранения и ан...
# 25  2020-05-14  Ubic создаст платформу для анализа данных о мо...
# 26  2020-04-16  Microsoft анонсировала запуск «Планетарного ко...
# 27  2021-11-13  Владимир Путин выступил с Германом Грефом на к...
# 28  2021-12-10  Интенсив для повышения квалификации: как испол...
# 29  2021-10-18  AI Journey Contest 2021: какие задачи мы подго...
# 30  2014-06-18  Обзор наиболее интересных материалов по анализ...
# 31  2014-06-30  Обзор наиболее интересных материалов по анализ...
# 32  2014-10-13  Обзор наиболее интересных материалов по анализ...
# 33  2017-06-27  Использование Python и Excel для обработки и а...
# 34  2014-07-28  Обзор наиболее интересных материалов по анализ...
# 35  2014-08-11  Обзор наиболее интересных материалов по анализ...
# 36  2014-09-14  Обзор наиболее интересных материалов по анализ...
# 37  2014-11-23  Обзор наиболее интересных материалов по анализ...
# 38  2017-12-25  Новый подход к спортивному анализу данных: как...
# 39  2014-10-05  Обзор наиболее интересных материалов по анализ...
#
#                                                  link
# 0   https://habr.com/ru/company/southbridge/news/t...
# 1   https://habr.com/ru/company/southbridge/news/t...
# 2                  https://habr.com/ru/news/t/498364/
# 3   https://habr.com/ru/company/raiffeisenbank/new...
# 4   https://habr.com/ru/company/southbridge/news/t...
# 5                  https://habr.com/ru/news/t/531402/
# 6                  https://habr.com/ru/news/t/654707/
# 7   https://habr.com/ru/company/itsumma/news/t/490...
# 8   https://habr.com/ru/company/epam_systems/news/...
# 9                  https://habr.com/ru/news/t/707698/
# 10  https://habr.com/ru/company/southbridge/news/t...
# 11                 https://habr.com/ru/news/t/505096/
# 12                 https://habr.com/ru/news/t/527858/
# 13                 https://habr.com/ru/news/t/695298/
# 14                 https://habr.com/ru/news/t/473926/
# 15                 https://habr.com/ru/news/t/581862/
# 16                 https://habr.com/ru/news/t/582682/
# 17  https://habr.com/ru/company/yandex_praktikum/n...
# 18                 https://habr.com/ru/news/t/684376/
# 19  https://habr.com/ru/company/southbridge/news/t...
# 20    https://habr.com/ru/company/yandex/blog/148443/
# 21    https://habr.com/ru/company/yandex/blog/334066/
# 22  https://habr.com/ru/company/factory5/blog/681846/
# 23  https://habr.com/ru/company/microsoft/blog/537...
# 24  https://habr.com/ru/company/sibur_official/blo...
# 25                 https://habr.com/ru/news/t/501944/
# 26                 https://habr.com/ru/news/t/497474/
# 27                 https://habr.com/ru/news/t/588991/
# 28  https://habr.com/ru/company/netologyru/news/t/...
# 29  https://habr.com/ru/company/sbercloud/news/t/5...
# 30                   https://habr.com/ru/post/226641/
# 31                   https://habr.com/ru/post/228187/
# 32                   https://habr.com/ru/post/240139/
# 33      https://habr.com/ru/company/otus/blog/331746/
# 34                   https://habr.com/ru/post/231323/
# 35                   https://habr.com/ru/post/232879/
# 36                   https://habr.com/ru/post/236757/
# 37                   https://habr.com/ru/post/243967/
# 38                  https://habr.comСсылка недоступна
# 39                   https://habr.com/ru/post/239247/

# %% [markdown]
# #Дополнительная часть (необязательная)

# %% [markdown]
# Функция из обязательной части задания должна быть расширена следующим образом:
#
# кроме списка ключевых слов для поиска необходимо объявить параметр с количеством страниц поисковой выдачи. Т.е. при передаче в функцию аргумента 4 необходимо получить материалы с первых 4 страниц результатов;
# в датафрейме должны быть столбцы с полным текстом найденных материалов и количеством лайков:
# <дата> - <заголовок> - <ссылка на материал> - <текст материала> - <количество лайков>

# %%
def habr_scrapper(query, page_count):

  #page_count = 1
  results = []
  for pg in range(1, page_count + 1):
    for search_word in query:
      base_url = 'https://habr.com'
      params = {'q': search_word,
                'target_type': 'posts',
                'order': 'relevance'}
      resp = requests.get(base_url + f'/ru/search/page{pg}/', params)
      soup = BeautifulSoup(resp.text)
      for article_tag in soup.find_all('article'):
        h2_tag = article_tag.find('h2')
        #print(h2_tag.prettify)
        title = h2_tag.get_text()
        #print(title)
        try:
          link = h2_tag.find('a').get('href')
        except:
          link = 'Ссылка недоступна'
        #print(link)
        date = article_tag.find('time').get('datetime')
        #print(date)
        rating = article_tag.find('span', attrs = {'class': 'tm-votes-meter__value'}).get_text()
        #print(rating)
        try:
          post_link = base_url + link
          post = requests.get(post_link)
          soup_post = BeautifulSoup(post.text)
          body = soup_post.find('div', attrs = {'class': 'article-formatted-body'}).get_text()
          
        except:
          body = 'Текст недоступен'
        results.append([date, title, link, body, rating])
      
  res_df = pd.DataFrame(results, columns = ['date', 'title', 'link', 'body', 'rating'])
  
  res_df['link'] = base_url + res_df['link']
  res_df['date'] = pd.to_datetime(res_df['date']).dt.date
  
  res_df.drop_duplicates()
  res_df.reset_index()
  return res_df

query = ['python', 'анализ данных']
page_count = 4
final_res_df = habr_scrapper(query, page_count)

# %%
final_res_df.head(50)
# Out:
#           date                                              title  \
# 0   2022-01-20  Курс «Python для инженеров». Старт 3 потока 31...
# 1   2021-12-13  Жаждущим автоматизации: открытый урок «ChatOps...
# 2   2020-04-21  Вышел Python 2.7.18, последний релиз ветки Pyt...
# 3   2021-07-06  Python Community Meetup 8/07: видео и материал...
# 4   2022-01-13  Открытый урок «Пишем Custom Prometheus Exporte...
# 5   2020-12-04  Python как компилируемый статически типизирова...
# 6   2022-03-08  Вышел мартовский релиз расширения Python для V...
# 7   2020-03-03  В начале этого года Python сместил Java и стал...
# 8   2021-11-16  EPAM разработала бесплатный курс по программир...
# 9   2022-12-26  Positive Technologies открыла доступ по запрос...
# 10  2022-08-19  Осталась неделя до старта 4 потока Python для ...
# 11  2020-06-03  Вышла версия 0.0.2 snakeware — дистрибутива Li...
# 12  2020-11-13  Создатель Python Гвидо ван Россум выходит на р...
# 13  2022-10-25                                  Вышел Python 3.11
# 14  2019-10-31  Создатель Python Гвидо ван Россум ушел из Drop...
# 15  2021-10-06          Вышел язык программирования Python 3.10.0
# 16  2021-10-11  Python вышел на первое место рейтинга TIOBE, и...
# 17  2022-06-03  «Тестирование веб-приложений на Python» — новы...
# 18  2022-08-24  Python, SQL, С и Java стали самыми популярными...
# 19  2022-12-05               Python или Golang: что учить в 2023?
# 20  2012-07-25                      Пять лет Школе анализа данных
# 21  2017-07-25                10 лет Школе анализа данных Яндекса
# 22  2022-08-10  Как за две недели проверить гипотезы применимо...
# 23  2021-01-14  Что такое бессерверный SQL? И как использовать...
# 24  2019-01-21  Как мы строим систему обработки, хранения и ан...
# 25  2020-05-14  Ubic создаст платформу для анализа данных о мо...
# 26  2020-04-16  Microsoft анонсировала запуск «Планетарного ко...
# 27  2021-11-13  Владимир Путин выступил с Германом Грефом на к...
# 28  2021-12-10  Интенсив для повышения квалификации: как испол...
# 29  2021-10-18  AI Journey Contest 2021: какие задачи мы подго...
# 30  2014-06-18  Обзор наиболее интересных материалов по анализ...
# 31  2014-06-30  Обзор наиболее интересных материалов по анализ...
# 32  2014-10-13  Обзор наиболее интересных материалов по анализ...
# 33  2017-06-27  Использование Python и Excel для обработки и а...
# 34  2014-07-28  Обзор наиболее интересных материалов по анализ...
# 35  2014-08-11  Обзор наиболее интересных материалов по анализ...
# 36  2014-09-14  Обзор наиболее интересных материалов по анализ...
# 37  2014-11-23  Обзор наиболее интересных материалов по анализ...
# 38  2017-12-25  Новый подход к спортивному анализу данных: как...
# 39  2014-10-05  Обзор наиболее интересных материалов по анализ...
# 40  2022-12-14               Юбилейный поток Python для инженеров
# 41  2020-09-16  Астрономам порекомендовали меньше использовать...
# 42  2022-01-15  Разработчик предложил устроить коммунистическу...
# 43  2022-05-18  Слёрм запускает 3-дневный интенсив по Python д...
# 44  2023-01-12                          3-месячный курс по Python
# 45  2022-03-18  24 марта Слёрм проведёт открытый урок «Первый ...
# 46  2022-04-22  TechnoMeetsPython. Онлайн митап о Python-разра...
# 47  2022-08-03   Последний поток Python для инженеров в этом году
# 48  2022-09-29  Асинхронное программирование на Python для джу...
# 49  2021-09-27  «Разработчикам вход запрещен» или курс «Python...
#
#                                                  link  \
# 0   https://habr.com/ru/company/southbridge/news/t...
# 1   https://habr.com/ru/company/southbridge/news/t...
# 2                  https://habr.com/ru/news/t/498364/
# 3   https://habr.com/ru/company/raiffeisenbank/new...
# 4   https://habr.com/ru/company/southbridge/news/t...
# 5                  https://habr.com/ru/news/t/531402/
# 6                  https://habr.com/ru/news/t/654707/
# 7   https://habr.com/ru/company/itsumma/news/t/490...
# 8   https://habr.com/ru/company/epam_systems/news/...
# 9                  https://habr.com/ru/news/t/707698/
# 10  https://habr.com/ru/company/southbridge/news/t...
# 11                 https://habr.com/ru/news/t/505096/
# 12                 https://habr.com/ru/news/t/527858/
# 13                 https://habr.com/ru/news/t/695298/
# 14                 https://habr.com/ru/news/t/473926/
# 15                 https://habr.com/ru/news/t/581862/
# 16                 https://habr.com/ru/news/t/582682/
# 17  https://habr.com/ru/company/yandex_praktikum/n...
# 18                 https://habr.com/ru/news/t/684376/
# 19  https://habr.com/ru/company/southbridge/news/t...
# 20    https://habr.com/ru/company/yandex/blog/148443/
# 21    https://habr.com/ru/company/yandex/blog/334066/
# 22  https://habr.com/ru/company/factory5/blog/681846/
# 23  https://habr.com/ru/company/microsoft/blog/537...
# 24  https://habr.com/ru/company/sibur_official/blo...
# 25                 https://habr.com/ru/news/t/501944/
# 26                 https://habr.com/ru/news/t/497474/
# 27                 https://habr.com/ru/news/t/588991/
# 28  https://habr.com/ru/company/netologyru/news/t/...
# 29  https://habr.com/ru/company/sbercloud/news/t/5...
# 30                   https://habr.com/ru/post/226641/
# 31                   https://habr.com/ru/post/228187/
# 32                   https://habr.com/ru/post/240139/
# 33      https://habr.com/ru/company/otus/blog/331746/
# 34                   https://habr.com/ru/post/231323/
# 35                   https://habr.com/ru/post/232879/
# 36                   https://habr.com/ru/post/236757/
# 37                   https://habr.com/ru/post/243967/
# 38                  https://habr.comСсылка недоступна
# 39                   https://habr.com/ru/post/239247/
# 40  https://habr.com/ru/company/southbridge/news/t...
# 41                 https://habr.com/ru/news/t/519414/
# 42                 https://habr.com/ru/news/t/645777/
# 43  https://habr.com/ru/company/southbridge/news/t...
# 44  https://habr.com/ru/company/southbridge/news/t...
# 45  https://habr.com/ru/company/southbridge/news/t...
# 46                 https://habr.com/ru/news/t/662437/
# 47  https://habr.com/ru/company/southbridge/news/t...
# 48  https://habr.com/ru/company/southbridge/news/t...
# 49  https://habr.com/ru/company/southbridge/news/t...
#
#                                                  body rating
# 0   Курс нацелен дать максимальную пользу, поэтому...    +10
# 1   21 декабря Слёрм проведёт открытый урок «ChatO...     +9
# 2   \r\n20 апреля 2020 года, спустя почти десять л...    +19
# 3   Первый открытый онлайн-митап сообщества, для к...     +3
# 4   19 января Слёрм проведёт открытый урок «Пишем ...    +10
# 5   По данным широко известного в узких кругах Tio...    +16
# 6   Вышел выпуск расширения Python для Visual Stud...      0
# 7   Согласно отчету RedMonk за январь 2020 года, P...    +31
# 8                                    Текст недоступен     +3
# 9   \n\r\nРазработчик решений для информационной б...     +2
# 10  29 августа в последний раз в этом году запусти...     +5
# 11  \n\r\n31 мая 2020 года разработчик Джош Мур (J...    +19
# 12  \n\r\nСоздатель языка программирования Python ...    +21
# 13  Разработчики опубликовали выпуск языка програм...    +11
# 14  \n\r\nСоздатель языка программирования Python ...    +23
# 15  В официальном блоге языка Python заявили о вых...    +12
# 16  TIOBE представила рейтинг популярности языков ...    +17
# 17  Сервис онлайн-образования Яндекс Практикум зап...     +1
# 18  Американский журнал IEEE Spectrum опубликовал ...     +3
# 19  Python и Golang — одни из самых востребованных...     +6
# 20  Ровно пять лет назад Яндекс объявил об открыти...    +21
# 21  Сегодня исполняется 10 лет Школе анализа данны...    +53
# 22  Всем привет, на связи российская компания Fact...     -1
# 23  Каждому специалисту по обработке и анализу дан...     +2
# 24  В начале 2018 года у нас активно пошел процесс...    +16
# 25  \n\r\nПравительство Москвы планирует создать о...    +14
# 26  \n\r\nВ рамках развития программы Microsoft AI...    +13
# 27  \n\r\n12 ноября президент России вместе с глав...     +8
# 28  14 декабря в Нетологии пройдёт вебинар, посвящ...     +4
# 29  Нарисовать карту лесных пожаров и распознать п...     +8
# 30  \r\nДанный выпуск дайджеста наиболее интересны...    +19
# 31  \r\nДанный выпуск обзора наиболее интересных м...    +24
# 32  \r\nПредставляю вашему вниманию очередной выпу...    +19
# 33  Если Вы только начинаете свой путь знакомства ...     +8
# 34  \r\nВ очередном выпуске обзора наиболее интере...    +20
# 35  \r\nПредставляю вашему вниманию очередной выпу...    +23
# 36  \r\nПредставляю вашему вниманию очередной выпу...    +25
# 37  \r\nПредставляю вашему вниманию очередной выпу...    +18
# 38                                   Текст недоступен    +21
# 39  \r\nПредставляю вашему вниманию очередной выпу...    +28
# 40  16 января весь Слёрм будет праздновать: старту...     +5
# 41  \n\r\nАстрономы из Лейденской обсерватории опу...    +22
# 42  \n\r\n14 января 2022 года разработчик jokteur ...     +7
# 43  24-26 июня пройдёт онлайн-интенсив для инженер...     +5
# 44  Рутинная работа уходит в прошлое: сегодня всем...     +7
# 45  Думаете, написать свою первую программу на Pyt...    +14
# 46  27 апреля в 18:00 собираем питонистов на YouTu...     +2
# 47  29 августа мы запускаем 4 поток курса «Python ...     +8
# 48  Как джуну выделиться на фоне таких же новичков...     +1
# 49  Полгода назад мы анонсировали первый поток кур...    +11

# %%
final_res_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160 entries, 0 to 159
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    160 non-null    object
#  1   title   160 non-null    object
#  2   link    160 non-null    object
#  3   body    160 non-null    object
#  4   rating  160 non-null    object
# dtypes: object(5)
# memory usage: 6.4+ KB
